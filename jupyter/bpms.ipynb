# %% [markdown]
# Print details about BPMs

# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), '..'))
from pytac import load_csv

# %% [markdown]
# Initialize the DIAD mode:

# %%
import cothread
lattice = load_csv.load('DIAD')

# %% [markdown]
# - Get the BPM elements:

# %%
bpms = lattice.get_elements('BPM')

# %% [markdown]
# - Print the values of the readback pvs on the b1 field:

# %%
for bpm in bpms:
    print('BPM {} at position {}'.format(bpm.get_device('x').name, bpm.s))
# Out:
# BPM SR01C-DI-EBPM-01 at position 4.38
# BPM SR01C-DI-EBPM-02 at position 8.8065
# BPM SR01C-DI-EBPM-03 at position 11.374
# BPM SR01C-DI-EBPM-04 at position 12.559
# BPM SR01C-DI-EBPM-05 at position 14.9425
# BPM SR01C-DI-EBPM-06 at position 18.005
# BPM SR01C-DI-EBPM-07 at position 21.27
# BPM SR02C-DI-EBPM-01 at position 26.93
# BPM SR02C-DI-EBPM-02 at position 30.360759
# BPM SR02C-DI-EBPM-03 at position 32.076129
# BPM SR02C-DI-EBPM-04 at position 33.97775
# BPM SR02C-DI-EBPM-05 at position 36.94325
# BPM SR02C-DI-EBPM-06 at position 39.615864
# BPM SR02C-DI-EBPM-07 at position 40.880528
# BPM SR02C-DI-EBPM-08 at position 43.991
# BPM SR03C-DI-EBPM-01 at position 49.651
# BPM SR03C-DI-EBPM-02 at position 54.0775
# BPM SR03C-DI-EBPM-03 at position 56.645
# BPM SR03C-DI-EBPM-04 at position 57.83
# BPM SR03C-DI-EBPM-05 at position 60.2135
# BPM SR03C-DI-EBPM-06 at position 63.276
# BPM SR03C-DI-EBPM-07 at position 66.541
# BPM SR04C-DI-EBPM-01 at position 72.301
# ...

# %% [markdown]
# Version 2 - to get the pv name of each bpm:

# %%
lattice.get_element_pv_names('BPM', 'x', 'readback')
# Out:
# ['SR01C-DI-EBPM-01:SA:X',
#  'SR01C-DI-EBPM-02:SA:X',
#  'SR01C-DI-EBPM-03:SA:X',
#  'SR01C-DI-EBPM-04:SA:X',
#  'SR01C-DI-EBPM-05:SA:X',
#  'SR01C-DI-EBPM-06:SA:X',
#  'SR01C-DI-EBPM-07:SA:X',
#  'SR02C-DI-EBPM-01:SA:X',
#  'SR02C-DI-EBPM-02:SA:X',
#  'SR02C-DI-EBPM-03:SA:X',
#  'SR02C-DI-EBPM-04:SA:X',
#  'SR02C-DI-EBPM-05:SA:X',
#  'SR02C-DI-EBPM-06:SA:X',
#  'SR02C-DI-EBPM-07:SA:X',
#  'SR02C-DI-EBPM-08:SA:X',
#  'SR03C-DI-EBPM-01:SA:X',
#  'SR03C-DI-EBPM-02:SA:X',
#  'SR03C-DI-EBPM-03:SA:X',
#  'SR03C-DI-EBPM-04:SA:X',
#  'SR03C-DI-EBPM-05:SA:X',
#  'SR03C-DI-EBPM-06:SA:X',
#  'SR03C-DI-EBPM-07:SA:X',
#  'SR04C-DI-EBPM-01:SA:X',
#  'SR04C-DI-EBPM-02:SA:X',
#  'SR04C-DI-EBPM-03:SA:X',
#  'SR04C-DI-EBPM-04:SA:X',
#  'SR04C-DI-EBPM-05:SA:X',
#  'SR04C-DI-EBPM-06:SA:X',
#  'SR04C-DI-EBPM-07:SA:X',
#  'SR05C-DI-EBPM-01:SA:X',
#  'SR05C-DI-EBPM-02:SA:X',
#  'SR05C-DI-EBPM-03:SA:X',
#  'SR05C-DI-EBPM-04:SA:X',
#  'SR05C-DI-EBPM-05:SA:X',
#  'SR05C-DI-EBPM-06:SA:X',
# ...

# %%
lattice.get_pv_names('BPM', 'y', 'readback')
# Out:
# ['SR01C-DI-EBPM-01:SA:Y',
#  'SR01C-DI-EBPM-02:SA:Y',
#  'SR01C-DI-EBPM-03:SA:Y',
#  'SR01C-DI-EBPM-04:SA:Y',
#  'SR01C-DI-EBPM-05:SA:Y',
#  'SR01C-DI-EBPM-06:SA:Y',
#  'SR01C-DI-EBPM-07:SA:Y',
#  'SR02C-DI-EBPM-01:SA:Y',
#  'SR02C-DI-EBPM-02:SA:Y',
#  'SR02C-DI-EBPM-03:SA:Y',
#  'SR02C-DI-EBPM-04:SA:Y',
#  'SR02C-DI-EBPM-05:SA:Y',
#  'SR02C-DI-EBPM-06:SA:Y',
#  'SR02C-DI-EBPM-07:SA:Y',
#  'SR02C-DI-EBPM-08:SA:Y',
#  'SR03C-DI-EBPM-01:SA:Y',
#  'SR03C-DI-EBPM-02:SA:Y',
#  'SR03C-DI-EBPM-03:SA:Y',
#  'SR03C-DI-EBPM-04:SA:Y',
#  'SR03C-DI-EBPM-05:SA:Y',
#  'SR03C-DI-EBPM-06:SA:Y',
#  'SR03C-DI-EBPM-07:SA:Y',
#  'SR04C-DI-EBPM-01:SA:Y',
#  'SR04C-DI-EBPM-02:SA:Y',
#  'SR04C-DI-EBPM-03:SA:Y',
#  'SR04C-DI-EBPM-04:SA:Y',
#  'SR04C-DI-EBPM-05:SA:Y',
#  'SR04C-DI-EBPM-06:SA:Y',
#  'SR04C-DI-EBPM-07:SA:Y',
#  'SR05C-DI-EBPM-01:SA:Y',
#  'SR05C-DI-EBPM-02:SA:Y',
#  'SR05C-DI-EBPM-03:SA:Y',
#  'SR05C-DI-EBPM-04:SA:Y',
#  'SR05C-DI-EBPM-05:SA:Y',
#  'SR05C-DI-EBPM-06:SA:Y',
# ...

# %%
lattice.get_family_s('BPM')
# Out:
# [4.38,
#  8.806500000000002,
#  11.374000000000002,
#  12.559000000000005,
#  14.942500000000006,
#  18.005000000000003,
#  21.270000000000003,
#  26.93,
#  30.360759,
#  32.076129,
#  33.977750000000015,
#  36.943250000000006,
#  39.61586400000001,
#  40.880528,
#  43.99100000000001,
#  49.65099999999999,
#  54.0775,
#  56.644999999999996,
#  57.83,
#  60.213499999999996,
#  63.276,
#  66.54100000000001,
#  72.30100000000003,
#  76.72750000000003,
#  79.29500000000004,
#  80.48000000000003,
#  82.86350000000003,
#  85.92600000000003,
#  89.19100000000003,
#  97.95100000000005,
#  102.37750000000005,
#  104.94500000000006,
#  106.13000000000005,
#  108.51350000000005,
#  111.57600000000005,
#  114.84100000000005,
#  120.60100000000007,
#  125.02750000000007,
#  127.59500000000008,
#  128.78000000000006,
#  131.16350000000003,
#  134.226,
#  137.49099999999999,
#  143.25100000000006,
#  147.6775,
#  150.245,
#  151.42999999999998,
#  153.81349999999995,
#  156.87599999999992,
# ...

# %%
import pytac
l = lattice.get_element_pv_names("BPM", "y", pytac.RB)

# %%
elements = lattice.get_elements("QUAD")
elements[0].get_fields()
# Out:
# {'live': ['b1']}

# %%
e
